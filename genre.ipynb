# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "movies_data.csv"
movie_data_df = pd.read_csv(csv_file)
movie_data_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
new_movie_data_df = movie_data_df[['name', 'genre', 'year']].copy()
new_movie_data_df.rename(columns={'name': 'title'}, inplace=True)
new_movie_data_df
# Out:
#                                                title      genre  year
# 0                                        The Shining      Drama  1980
# 1                                    The Blue Lagoon  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     Action  1980
# 3                                          Airplane!     Comedy  1980
# 4                                         Caddyshack     Comedy  1980
# ...                                              ...        ...   ...
# 7663                                    More to Life      Drama  2020
# 7664                                     Dream Round     Comedy  2020
# 7665                                   Saving Mbango      Drama  2020
# 7666                                    It's Just Us      Drama  2020
# 7667                                       Tee em el     Horror  2020
#
# [7668 rows x 3 columns]

# %%
from pathlib import Path  
filepath = Path('clean_movie_genre_dt.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
new_movie_data_df.to_csv(filepath, index =False)
