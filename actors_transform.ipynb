# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
actors1_file = "resources/actors1.csv"
actors1 = pd.read_csv(actors1_file)
# actors1 = actors_df.dropna(axis=0)
# actors1 = actors_df.loc[actors_df['birthYear'] != 'N']

actors2_file = "resources/actors2.csv"
actors2 = pd.read_csv(actors2_file)

actors3_file = "resources/actors3.csv"
actors3 = pd.read_csv(actors3_file)

actors4_file = "resources/actors4.csv"
actors4 = pd.read_csv(actors4_file)

actors5_file = "resources/actors5.csv"
actors5 = pd.read_csv(actors5_file)

actors6_file = "resources/actors6.csv"
actors6 = pd.read_csv(actors6_file)

actors7_file = "resources/actors7.csv"
actors7 = pd.read_csv(actors7_file)

actors8_file = "resources/actors8.csv"
actors8 = pd.read_csv(actors8_file)

actors9_file = "resources/actors9.csv"
actors9 = pd.read_csv(actors9_file)

actors10_file = "resources/actors10.csv"
actors10 = pd.read_csv(actors10_file)

actors11_file = "resources/actors11.csv"
actors11 = pd.read_csv(actors11_file)

# %%
frames = [actors1, actors2, actors3, actors4, actors5, actors6, actors7, actors8, actors9, actors10, actors11]
actors_df = pd.concat(frames)

# %%
actors_df = actors_df.loc[actors_df['birthYear'] != '\\N' ]
actors_df
# Out:
#             nconst        primaryName birthYear deathYear  \
# 0        nm0000001       Fred Astaire      1899      1987
# 1        nm0000002      Lauren Bacall      1924      2014
# 2        nm0000003    Brigitte Bardot      1934        \N
# 3        nm0000004       John Belushi      1949      1982
# 4        nm0000005     Ingmar Bergman      1918      2007
# ...            ...                ...       ...       ...
# 1012395  nm9993432       Albert Minns      1920      1985
# 1012396  nm9993434  Richard Blackmarr      1929      2013
# 1012397  nm9993435       William Riva      1919      1999
# 1012398  nm9993436     Frank J. Gaily      1915      2008
# 1012623  nm9993675     Ebrahim Alkazi      1925      2020
#
#                            primaryProfession  \
# 0             soundtrack,actor,miscellaneous
# 1                         actress,soundtrack
# 2        actress,soundtrack,music_department
# 3                    actor,soundtrack,writer
# ...

# %%
actors_df=actors_df.rename({"nconst": "artist_id",
                           "primaryName":"artist",
                           "knownForTitles": "imdb_id"}, axis=1)
actors_df
# Out:
#          artist_id             artist birthYear deathYear  \
# 0        nm0000001       Fred Astaire      1899      1987
# 1        nm0000002      Lauren Bacall      1924      2014
# 2        nm0000003    Brigitte Bardot      1934        \N
# 3        nm0000004       John Belushi      1949      1982
# 4        nm0000005     Ingmar Bergman      1918      2007
# ...            ...                ...       ...       ...
# 1012395  nm9993432       Albert Minns      1920      1985
# 1012396  nm9993434  Richard Blackmarr      1929      2013
# 1012397  nm9993435       William Riva      1919      1999
# 1012398  nm9993436     Frank J. Gaily      1915      2008
# 1012623  nm9993675     Ebrahim Alkazi      1925      2020
#
#                            primaryProfession  \
# 0             soundtrack,actor,miscellaneous
# 1                         actress,soundtrack
# 2        actress,soundtrack,music_department
# 3                    actor,soundtrack,writer
# ...

# %%
clean_actors_df = actors_df[["artist_id", "artist", "imdb_id"]]
clean_actors_df
# Out:
#          artist_id             artist                                  imdb_id
# 0        nm0000001       Fred Astaire  tt0031983,tt0050419,tt0053137,tt0072308
# 1        nm0000002      Lauren Bacall  tt0117057,tt0038355,tt0071877,tt0037382
# 2        nm0000003    Brigitte Bardot  tt0054452,tt0057345,tt0049189,tt0056404
# 3        nm0000004       John Belushi  tt0078723,tt0077975,tt0080455,tt0072562
# 4        nm0000005     Ingmar Bergman  tt0050986,tt0050976,tt0083922,tt0060827
# ...            ...                ...                                      ...
# 1012395  nm9993432       Albert Minns                                tt0189339
# 1012396  nm9993434  Richard Blackmarr                                tt0189339
# 1012397  nm9993435       William Riva                      tt0300836,tt0189339
# 1012398  nm9993436     Frank J. Gaily                                tt0189339
# 1012623  nm9993675     Ebrahim Alkazi                                       \N
#
# ...

# %%
clean_actors_df.to_csv('artist.csv', index=False, encoding='utf-8')
